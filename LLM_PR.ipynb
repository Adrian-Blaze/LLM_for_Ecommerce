# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- --------
# aiohttp                 3.8.4
# aiosignal               1.3.1
# asttokens               2.2.1
# async-timeout           4.0.2
# attrs                   23.1.0
# backcall                0.2.0
# certifi                 2023.5.7
# charset-normalizer      3.1.0
# colorama                0.4.6
# comm                    0.1.3
# dataclasses-json        0.5.8
# debugpy                 1.6.7
# decorator               5.1.1
# executing               1.2.0
# frozenlist              1.3.3
# greenlet                2.0.2
# idna                    3.4
# ipykernel               6.23.2
# ipython                 8.14.0
# jedi                    0.18.2
# jupyter_client          8.2.0
# jupyter_core            5.3.1
# langchain               0.0.205
# langchainplus-sdk       0.0.13
# marshmallow             3.19.0
# marshmallow-enum        1.5.1
# matplotlib-inline       0.1.6
# multidict               6.0.4
# ...

# %%
import os
import pandas as pd
from langchain.document_loaders import CSVLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
import streamlit as st

# %%
df = pd.read_csv(f'C:/Users/user/Desktop/scoop_pricelist.csv')
df
# Out:
#          SKU                                               Item  \
# 0       4G03  Tenda 4G LTE 2.4GHz 300Mbps Wireless Router | ...
# 1       4G09  Tenda 4G LTE6 Dual Band 1200Mbps Wireless Rout...
# 2     ACB-AC  Ubiquiti UISP airCube AC WiFi Access Point | A...
# 3    ACB-ISP  Ubiquiti UISP airCube ISP WiFi Access Point | ...
# 4      AF-11         Ubiquiti UISP airFiber 11GHz Radio | AF-11
# ..       ...                                                ...
# 825      YT1                           EGA Trunking 16mm x 16mm
# 826      YT2                           EGA Trunking 25mm x 16mm
# 827      YT4                           EGA Trunking 40mm x 25mm
# 828      YT5                           EGA Trunking 40mm x 40mm
# 829      YT7                    Half Moon Trunking 70mm x 10mm
#
#      Capetown_stock  Johannesburg_stock  Durban_stock  Total Stock Quantity  \
# 0                 0                   2             0                     2
# ...

# %%
df.describe()
# Out:
#        Capetown_stock  Johannesburg_stock  Durban_stock  Total Stock Quantity  \
# count      830.000000          830.000000    830.000000            830.000000
# mean       258.960241          331.577108     58.592771            649.130120
# std       2116.184885         2621.385633    487.103785           5146.733854
# min          0.000000            0.000000      0.000000              0.000000
# 25%          2.250000            3.000000      1.000000             11.000000
# 50%         17.000000           25.000000      5.000000             54.000000
# 75%         67.000000          108.750000     18.000000            220.750000
# max      52418.000000        69356.000000  11852.000000         133626.000000
#
#        Dealer Price(R)  Retail Price(R)
# count       830.000000       830.000000
# mean       1918.620000      2754.569747
# std        3721.730391      5346.141522
# min           0.650000         0.950000
# 25%         115.000000       167.500000
# ...

# %%
os.environ["OPENAI_API_KEY"] = "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"
#os.environ["OPENAI_API_KEY"] = 'org-VWzHxYOBgo3NEvQQxVFlxK0P'

# %%
# Load the documents
loader = CSVLoader(file_path=f'C:/Users/user/Desktop/scoop_pricelist.csv')

# %%
from langchain.agents import create_csv_agent

# %%
csv = f'C:/Users/user/Desktop/scoop_pricelist.csv'

# %%
agent = create_csv_agent(OpenAI(temperature=0), csv, verbose=True)

# %%
#!pip install tabulate

# %%
user_question = input("Enter your question: ")

# %%
agent.run(user_question)
# Out:
# > Entering new  chain...
# Thought: this question has nothing to do with the dataframe
# Action: None
# Action Input: None
# Observation: None is not a valid tool, try another one.
# Thought: I should use a different tool
# Action: python_repl_ast
# Action Input: print("Bill Gates is an American business magnate, investor, author, and philanthropist.")
# Observation: Bill Gates is an American business magnate, investor, author, and philanthropist.
#
# Thought: I now know the final answer
# Final Answer: Bill Gates is an American business magnate, investor, author, and philanthropist.
#
# > Finished chain.
# 'Bill Gates is an American business magnate, investor, author, and philanthropist.'
